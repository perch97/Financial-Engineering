# %%
# !wget -nc https://lazyprogrammer.me/course_files/sp500sub.csv
# Out:
# --2023-03-26 20:04:17--  https://lazyprogrammer.me/course_files/sp500sub.csv
# Resolving lazyprogrammer.me (lazyprogrammer.me)... 2606:4700:3030::ac43:d5a6, 2606:4700:3031::6815:17d2, 104.21.23.210, ...
# Connecting to lazyprogrammer.me (lazyprogrammer.me)|2606:4700:3030::ac43:d5a6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25473876 (24M) [text/csv]
# Saving to: ‘sp500sub.csv’
#
# sp500sub.csv        100%[===================>]  24.29M  3.20MB/s    in 8.0s
#
# 2023-03-26 20:04:26 (3.04 MB/s) - ‘sp500sub.csv’ saved [25473876/25473876]

# %%
import pandas as pd
df = pd.read_csv('sp500sub.csv',index_col = 'Date', parse_dates=True)

# %%
df.head()
# Out:
#              Open   High    Low  Close  Adj Close     Volume  Name
# Date
# 2010-01-04   9.22   9.51   9.17   9.50       9.50  1865400.0  INCY
# 2010-01-05   9.51  10.29   9.45  10.27      10.27  7608900.0  INCY
# 2010-01-06  10.38  11.09  10.35  11.00      11.00  8046700.0  INCY
# 2010-01-07  11.00  11.06  10.62  10.82      10.82  3680300.0  INCY
# 2010-01-08  10.82  11.00  10.75  10.94      10.94  1529300.0  INCY

# %% [markdown]
# # Google close and adjusted close

# %%
goog = df[df['Name']=='GOOG']
goog[['Close','Adj Close']].plot(figsize=(10,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
[i  for i in df['Name'].unique() if i.startswith('AA')]
# Out:
# ['AAPL', 'AAP']

# %% [markdown]
# # Apple close and adjusted close

# %%
aapl = df[df['Name']=='AAPL']
aapl[['Close','Adj Close']].plot(figsize=(10,10))
# Out:
# <AxesSubplot:xlabel='Date'>
